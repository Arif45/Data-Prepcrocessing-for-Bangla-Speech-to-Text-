# %%
import os
path = '/home/arif/Google Data'
str=_"asr_bengali ("
files = os.listdir(path)
i = 1
for file in files:
    sample_name = os.path.basename(file).split('.')[0]
    print(sample_name)
    os.rename(os.path.join(path, file), os.path.join(path, Bangla+"("+str(i)'.wav'))
    i = i+1
# Out:
# f9c12dac78
# f9cc0c3022
# f90c9bc166
# f951c6e4a8
# f9f10eaa37
# f9161b2125
# f92f2daaec
# f97c5012df
# f9061bee95
# f9f75f8d05
# f9b012eb74
# f9f55a02f6
# f9b972b8e5
# f97424645c
# f9ef2e8852
# f9edad8551
# f928cc2904
# f9e747b36d
# f9b16473ee
# f907677c3c
# f9e4384681
# f9ca8cbaee
# f9e329c6f6
# f9dbac9d04
# f997aff290
# f94f457a29
# f911bd4bae
# f9e4823e73
# f94d9df0d2
# f9325b9d61
# f9aa7d7309
# f992c4aa54
# f9b678d08c
# f97ca6ca9e
# f90d2ecb62
# f9de4899ac
# f939200180
# f93da78d04
# f99c5b9583
# f969db50b8
# f9122c8691
# f9a3293b7a
# f917199831
# f9e92c874f
# f99031abd2
# f9e669aa0b
# f9dd785438
# f9a91c21d2
# f9e29720ff
# f9fd8b26ac
# f9e38fc349
# f9aa34ee27
# f9db4eb493
# f99fd23b59
# f912bd24ab
# f99c8039b3
# f949e3750e
# f944b8dc89
# f9bd742af3
# f91dd6848d
# f9033d30a5
# f9c104586d
# f9d60d91de
# f9f95014e8
# f9ff6f914c
# f907c92f37
# f93a82919f
# f996ec55c6
# f9fd61eb0a
# f9533fc959
# f9ef1127a9
# f9a204a3de
# f973818060
# f9b3318a9c
# f99c8dc75a
# f9bccef64a
# ...
