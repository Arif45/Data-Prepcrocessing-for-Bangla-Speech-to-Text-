# %%
file = open("copy.txt", "w") 
s = "আমার নাম মেহেদি"
file.write(s) 
file.close()

# %%
import re
# string = "হয়নি\n7a21d53c07\tc3cb3\tনির্বাচন"
string = "হয়নি \n,..,.,\\\\\\\\\\\\(\t))()((())))()&*((নির্বাচন"
l = len(string)
# s = re.sub('[\na-zA-Z\t0-9]*', '', string)
s = re.sub('[\t\n,\)(!@$%^&*`~.?(\\\)]*', '', string)
# s = re.sub('[(\\\)]*', '', s) 
print(s)
# l = len(s)
# for i in range(0,l):
#     if s[i] == '়':
#         print (s[i])
# vals = re.sub('[\na-zA-Z\t0-9]*', ',', string)
# print (vals)
# Out:
# হয়নি নির্বাচন

# %%
import csv

words = set()

with open('01.tsv', encoding="utf8") as csv_file:
    csv_reader = csv.reader(csv_file, delimiter='\t')
#     words = set()
    for row in csv_reader:
        text = row[2]
        print(text)
        a = text.split(" ")
# print ("a: ",row[0], "  === ", row[1], " === ", a)
        for val in a:
            words.add(val)
# for w in words:
#     print ("words: ",w)
# Out:
# উত্তর খুঁজিতে খুঁজিতে
# লেখাপড়া করতে পারতাম
# ধর্মের কাজ সেভাবে করবো
# আটাশটি ওষুধের দোকানে
# মলিন কমল-মালা
# মিথ্যা ও ষড়যন্ত্র করে
# তারা সকল
# জাপানে নববর্ষ উপলক্ষে বানানো হয় চালের কেক, যাকে বলা হয় ‘মোশি’।
# বিছানা থেকে
# বাংলাদেশ নাটোক
# সাড়ে আট টার দিকে
# আপাতত নিরাপদ আশ্রয়
# ইলিয়াস তরুণ পাঠক শ্রেণীর
# রাজ জানান
# বালিতে আন্তর্জাতিক বিমানবন্দর
# শিবম শর্মা ও লক্ষ্মীপতি বালাজি
# অনুপ্রেরণা জোগাচ্ছে
# মোট দেশজ উতপাদন বৃদ্ধির
# পালন করবে
# দাঙ্গাবাজের দল
# আগে এর প্রতি গ্রামের
# মূল প্রস্তাব
# সেই আয়াতটি অর্থাৎ
# নাশকতাকারী হিসেবে
# মনে হবে বুঝি
# ঘোড়া প্রস্তুত
# তখন গুপি তাকে বলল
# দ্বিমুখী অডিও
# বাংলাদেশের জন্য কোন সুযোগ
# আলোচনায় আসেন তিনি
# নেতা-কর্মীদের সঙ্গে
# দিনাজপুরে
# আইফোনের বিক্রির
# ও বোনের আপদ্ পড়িলে
# লর্ড কার্জন কিসের ভিত্তিতে
# উন্নয়ন সম্ভব নয়
# অবশ্য উদ্ধার করা দুরূহ
# সম্ভোগ
# ডাকাতদল অস্ত্রের মুখে
# পাবনা
# আত্মরক্ষার প্রয়োজনটাই
# সুচিত্রা সেনের পারিবারিক নাম ছিল রমা দাশগুপ্ত।
# অবধারণ করিয়া রাখিয়াছি
# গরিব বাঙ্গালীর ছেলে সাহেব হইয়া
# ...
